# %% [markdown]
# <a href="https://colab.research.google.com/github/HashimHilal-QUT/LLM/blob/main/Beginners%20Guide%20to%20LLM/Beginners_Guide_LLM_on_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# This Notebook is a very simple demonstration of AI LLM in Colab.
#
# It does not require any API Key or a paid subscription account.
#
# With just a few lines of code, you can now perform a variety of tasks:
#
# - Generate text
# - Translate languages
# - Write creative content
# - Categorize text

# %%
# @title List available models
from google.colab import ai

selected_model = ai.list_models()
print(selected_model)
# Out:
# ['google/gemini-2.5-flash', 'google/gemini-2.5-flash-lite']

# %% [markdown]
# Choosing a Model
# The model names give you a hint about their capabilities and intended use:
#
# Pro: These are the most capable models, ideal for complex reasoning, creative tasks, and detailed analysis.
#
# Flash: These models are optimized for high speed and efficiency, making them great for summarization, chat applications, and tasks requiring rapid responses.
#
# Gemma: These are lightweight, open-weight models suitable for a variety of text generation tasks and are great for experimentation.

# %% [markdown]
# Enter a prompt here, for example:
#
# What is the Capital of France and give some good tourism spots

# %%
UserInput = input("Please enter your prompt for the AI model: ")
# Out:
# Please enter your prompt for the AI model: What is the Capital of France and give some good tourism spots

# %%
# @title Simple batch generation example
# Only text-to-text input/output is supported
from google.colab import ai

response = ai.generate_text(UserInput)
print(response)
# Out:
# The capital of France is **Paris**.
#
# Here are some fantastic tourism spots across France, offering a diverse range of experiences:
#
# **In and Around Paris:**
#
# 1.  **Eiffel Tower:** The iconic symbol of Paris, offering breathtaking panoramic views of the city. A must-do for any first-time visitor.
# 2.  **Louvre Museum:** Home to thousands of works of art, including the Mona Lisa and the Venus de Milo. It's one of the world's largest and most visited museums.
# 3.  **Notre Dame Cathedral:** (Even post-fire, its history and ongoing restoration make it incredibly significant). A magnificent Gothic cathedral, a testament to centuries of French history and architecture.
# 4.  **Palace of Versailles:** A stunning royal château just outside Paris, famous for its opulent Hall of Mirrors, grand apartments, and vast, meticulously manicured gardens.
# ...

# %%
# @title Select a model
selected_model = 'google/gemini-2.5-flash-lite' # @param ["google/gemini-2.5-flash", "google/gemini-2.5-flash-lite"]

# %%
# @title Choose a different model
from google.colab import ai

response = ai.generate_text(UserInput, model_name=selected_model)
print(response)
# Out:
# The capital of France is **Paris**.
#
# Here are some of the most iconic and highly recommended tourism spots in Paris:
#
# **Iconic Landmarks & Must-Sees:**
#
# *   **Eiffel Tower:** The undisputed symbol of Paris. You can go up to different levels for breathtaking panoramic views of the city, especially stunning at sunset and when it sparkles at night.
# *   **Louvre Museum:** Home to an unparalleled collection of art and artifacts, including the Mona Lisa, Venus de Milo, and the Winged Victory of Samothrace. Plan for at least half a day, if not more, to explore its vast halls.
# *   **Notre-Dame Cathedral:** While currently undergoing restoration after the 2019 fire, the exterior remains a magnificent example of Gothic architecture. You can still admire its grandeur from the outside and learn about its history.
# ...

# %% [markdown]
# For longer text generations, you can stream the response. This displays the output token by token as it's generated, rather than waiting for the entire response to complete. This provides a more interactive and responsive experience. To enable this, simply set stream=True.

# %%
# @title Simple streaming example
from google.colab import ai

stream = ai.generate_text(UserInput, stream=True)
for text in stream:
  print(text, end='')
# Out:
# The capital of France is **Paris**.
#
# Here are some excellent tourism spots in and around Paris:
#
# 1.  **Eiffel Tower:** The iconic symbol of Paris. You can ascend to the top for breathtaking panoramic views of the city, or simply admire it from the Champ de Mars.
# 2.  **The Louvre Museum:** Home to thousands of works of art, including Leonardo da Vinci's "Mona Lisa" and the "Venus de Milo." It's one of the world's largest and most visited museums.
# 3.  **Notre-Dame Cathedral:** A masterpiece of French Gothic architecture. While undergoing extensive restoration after the 2019 fire, its exterior is still incredibly impressive and its history profound.
# 4.  **Arc de Triomphe & Champs-Élysées:** The Arc de Triomphe stands proudly at the western end of the Champs-Élysées, offering fantastic views from its summit. The Champs-Élysées itself is a grand avenue famous for luxury shopping, cinemas, and cafes.
# ...

# %%
#@title Text formatting setup
#code is not necessary for colab.ai, but is useful in fomatting text chunks
import sys

class LineWrapper:
    def __init__(self, max_length=80):
        self.max_length = max_length
        self.current_line_length = 0

    def print(self, text_chunk):
        i = 0
        n = len(text_chunk)
        while i < n:
            start_index = i
            while i < n and text_chunk[i] not in ' \n': # Find end of word
                i += 1
            current_word = text_chunk[start_index:i]

            delimiter = ""
            if i < n: # If not end of chunk, we found a delimiter
                delimiter = text_chunk[i]
                i += 1 # Consume delimiter

            if current_word:
                needs_leading_space = (self.current_line_length > 0)

                # Case 1: Word itself is too long for a line (must be broken)
                if len(current_word) > self.max_length:
                    if needs_leading_space: # Newline if current line has content
                        sys.stdout.write('\n')
                        self.current_line_length = 0
                    for char_val in current_word: # Break the long word
                        if self.current_line_length >= self.max_length:
                            sys.stdout.write('\n')
                            self.current_line_length = 0
                        sys.stdout.write(char_val)
                        self.current_line_length += 1
                # Case 2: Word doesn't fit on current line (print on new line)
                elif self.current_line_length + (1 if needs_leading_space else 0) + len(current_word) > self.max_length:
                    sys.stdout.write('\n')
                    sys.stdout.write(current_word)
                    self.current_line_length = len(current_word)
                # Case 3: Word fits on current line
                else:
                    if needs_leading_space:
                        # Define punctuation that should not have a leading space
                        # when they form an entire "word" (token) following another word.
                        no_leading_space_punctuation = {
                            ",", ".", ";", ":", "!", "?",        # Standard sentence punctuation
                            ")", "]", "}",                     # Closing brackets
                            "'s", "'S", "'re", "'RE", "'ve", "'VE", # Common contractions
                            "'m", "'M", "'ll", "'LL", "'d", "'D",
                            "n't", "N'T",
                            "...", "…"                          # Ellipses
                        }
                        if current_word not in no_leading_space_punctuation:
                            sys.stdout.write(' ')
                            self.current_line_length += 1
                    sys.stdout.write(current_word)
                    self.current_line_length += len(current_word)

            if delimiter == '\n':
                sys.stdout.write('\n')
                self.current_line_length = 0
            elif delimiter == ' ':
                # If line is full and a space delimiter arrives, it implies a wrap.
                if self.current_line_length >= self.max_length:
                    sys.stdout.write('\n')
                    self.current_line_length = 0

        sys.stdout.flush()

# %%
# @title Formatted streaming example
from google.colab import ai

wrapper = LineWrapper()
for chunk in ai.generate_text(UserInput, model_name= selected_model, stream=True):
  wrapper.print(chunk)
# Out:
# The capital of France is **Paris**.
#
# Paris is renowned for its incredible wealth of tourism spots. Here are some of
# the absolute must-sees:
#
# **Iconic Landmarks & Architecture:**
#
# * **Eiffel Tower:** The undisputed symbol of Paris. You can ascend to the top
# for breathtaking panoramic views of the city. Consider visiting at night when it
# sparkles!
# * **Louvre Museum:** Home to thousands of works of art, including the Mona Lisa,
# Venus de Milo, and Wing ed Victory. It's massive, so plan your visit and
# prioritize what you want to see.
# * **Notre-Dame Cathedral:** While undergoing restoration after the fire, it
# remains an important historical and architectural landmark. You can still admire
# its exterior and the ongoing efforts.
# * **Arc de Triomphe:** Standing at the western end of the Champs-Élysées, you
# can climb to the top for a different perspective of the city and the twelve
# avenues radiating from it.
# ...
